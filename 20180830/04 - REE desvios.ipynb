# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d = pd.read_csv("/home/rlx/Downloads/LIQUIDACIONES/DATOS/ZIP W2M/C2_reprdesv_20180501_18XWMARK-1234-18",
               delimiter=";", skiprows=2)
d.columns=[ "fecha", "periodo", "c1", "c2", "c3", "c4", "c5", "unidad", "nada"]
d = d[[i for i in d.columns if i!="nada"]].dropna()

# %%
d.head()
# Out:
#         fecha  periodo      c1    c2     c3     c4   c5   unidad
# 0  01/05/2018      1.0   0.033   0.0  0.033  0.033  0.0  TGIROGA
# 1  01/05/2018      1.0   0.000   0.0  0.000  0.000  0.0  TINGARO
# 2  01/05/2018      1.0  25.873  25.8  0.073  0.073  0.0  TSMURES
# 3  01/05/2018      1.0  23.800  23.6  0.200  0.200  0.0  TTABLER
# 4  01/05/2018      1.0  12.459  12.0  0.459  0.459  0.0  TUEMADE

# %% [markdown]
# ## número de datos por cada unidad

# %%
d.unidad.value_counts()
# Out:
# HLASJO     24
# TCTAULE    24
# EALTIPL    24
# EPOUSAD    24
# TEMASA     24
# ZABU       24
# RMU1       24
# TCMATEO    24
# EYWMARK    24
# EBECERR    24
# HHONZA     24
# HSEGEN     24
# SFWMARK    24
# BERR2      24
# BERR1      24
# SZWMARK    24
# ECENDER    24
# FYWMARK    24
# TGIRSA     24
# RSOGBI     24
# RSMURFT    24
# HYWMARK    24
# EREVALD    24
# EEVOLD     24
# TSMURES    24
# TGIRCO     24
# TSOGAM     24
# HIDEUR     24
# ESIAM      24
# LBAT       24
#            ..
# TTABLER    24
# ABA1       24
# ABA2       24
# ETO1       24
# BERJUCA    24
# FSEALRI    24
# RSMUNAV    24
# LMA1       24
# RSOGAM     24
# ULEA       24
# ECHO       24
# ERONDA     24
# EGESTNV    24
# SOL2       24
# TCAVLO     24
# TUEMADE    24
# TQUALI     24
# TNPCE      24
# EPALOM     24
# HRWMARK    24
# FHEPAT2    24
# FHEPAT1    24
# EMONPAS    24
# TINGARO    24
# FFWMARK    24
# HFWMARK    24
# TEUROAT    24
# EMONGU     24
# TKERAB     24
# TFOREST    23
# ...

# %% [markdown]
# ## algunas unidades aleatorias

# %%
units = [i for i in  np.unique(d.unidad) if "WMARK" not in i]
units_wmark = [i for i in  np.unique(d.unidad) if "WMARK" in i]
len(units), len(units_wmark)
# Out:
# (56, 11)

# %% [markdown]
# ## unidades *WMARK

# %%
plt.figure(figsize=(10,3))
for unit in units_wmark:
    k = d[d.unidad==unit]
    plt.plot(k.periodo, k.c1, label=unit)
plt.xlabel("periodo")
plt.ylabel("columna c1")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## otras unidades

# %%
for i in range(5):
    plt.figure(figsize=(10,3))
    for unit in units[i*10:(i+1)*10]:
        k = d[d.unidad==unit]
        plt.plot(k.periodo, k.c1, label=unit)
    plt.xlabel("periodo")
    plt.ylabel("columna c1")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
plt.figure(figsize=(10,3))
for col in ["c%d"%i for i in range(1,6)]:
    k = d[d.unidad=="EFWMARK"]
    plt.plot(k.periodo, k[col], label="columna "+col)
plt.xlabel("periodo")
plt.ylabel("valor")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title("EFWMARK")
# Out:
# Text(0.5,1,'EFWMARK')
